# %%
import imblearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE
import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/bank'
engine = create_engine(connection_string)

# %%
query = '''SELECT r.rental_date, f.film_id, f.title, f. rental_duration, f.rental_rate, f.length, f.rating,
CASE WHEN ((MONTH(r.rental_date) = 8) AND (YEAR(r.rental_date) = 2005)) THEN 1
ELSE 0
END as was_rented0805
FROM sakila.rental r
JOIN sakila.inventory i
USING (inventory_id)
JOIN sakila.film f
USING (film_id);'''

movies = pd.read_sql_query(query, engine)
movies.head()
# Out:
#           rental_date  film_id             title  rental_duration  \
# 0 2005-07-08 19:03:15        1  ACADEMY DINOSAUR                6
# 1 2005-08-02 20:13:10        1  ACADEMY DINOSAUR                6
# 2 2005-08-21 21:27:43        1  ACADEMY DINOSAUR                6
# 3 2005-05-30 20:21:07        1  ACADEMY DINOSAUR                6
# 4 2005-06-17 20:24:00        1  ACADEMY DINOSAUR                6
#
#    rental_rate  length rating  was_rented0805
# 0         0.99      86     PG               0
# 1         0.99      86     PG               1
# 2         0.99      86     PG               1
# 3         0.99      86     PG               0
# 4         0.99      86     PG               0

# %%
# Converting the rating into numerical for easier comparisson

movies['rating'].replace(to_replace='G', value=0, inplace=True, limit=None, regex=False, method='0')
movies['rating'].replace(to_replace='PG', value=1, inplace=True, limit=None, regex=False, method='1')
movies['rating'].replace(to_replace='PG-13', value=0, inplace=True, limit=None, regex=False, method='2')
movies['rating'].replace(to_replace='R', value=0, inplace=True, limit=None, regex=False, method='3')
movies['rating'].replace(to_replace='NC-17', value=0, inplace=True, limit=None, regex=False, method='4')

# %%
# We have the "was_rented column" so the rental_date column becomes redundant
# Titles are also redundant seeing as we have film_id

movies = movies.drop(['rental_date','title'], axis=1)
movies.head()
# Out:
#    film_id  rental_duration  rental_rate  length  rating  was_rented0805
# 0        1                6         0.99      86       1               0
# 1        1                6         0.99      86       1               1
# 2        1                6         0.99      86       1               1
# 3        1                6         0.99      86       1               0
# 4        1                6         0.99      86       1               0

# %%
# X/y split

X = movies.drop(['was_rented0805'], axis=1)
y = movies['was_rented0805']

# %%
correlations_matrix = movies.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# As seen below there are no more columns that should be dropped as he correlation is low between all features

# %%
# Train/Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
X_train.head()
# Out:
#        film_id  rental_duration  rental_rate  length  rating
# 7177       445                5         2.99     100       0
# 11307      708                4         4.99     112       0
# 12667      789                7         2.99      79       0
# 9897       619                3         0.99     161       0
# 12215      764                3         4.99     150       0

# %%
# Normalizing Training Values
minmaxset = X_train[['film_id', 'rental_duration', 'rental_rate', 'length', 'rating']]

# Normalizing data: MINMAXSCALER
minmaxnorm = MinMaxScaler().fit(minmaxset)
x_norm = minmaxnorm.transform(minmaxset)
print(x_norm.shape)
minmax=pd.DataFrame(x_norm, columns=minmaxset.columns)
minmax
# Out:
# (12835, 5)
#         film_id  rental_duration  rental_rate    length  rating
# 0      0.444444             0.50          0.5  0.388489     0.0
# 1      0.707708             0.25          1.0  0.474820     0.0
# 2      0.788789             1.00          0.5  0.237410     0.0
# 3      0.618619             0.00          0.0  0.827338     0.0
# 4      0.763764             0.00          1.0  0.748201     0.0
# ...         ...              ...          ...       ...     ...
# 12830  0.355355             0.50          0.5  0.402878     0.0
# 12831  0.495495             0.00          0.0  0.956835     0.0
# 12832  0.085085             0.75          1.0  0.539568     0.0
# 12833  0.097097             0.25          1.0  0.194245     0.0
# 12834  0.820821             0.75          0.0  0.992806     0.0
#
# [12835 rows x 5 columns]

# %%
# Normalizing Testing Values
minmaxsettest = X_test[['film_id', 'rental_duration', 'rental_rate', 'length', 'rating']]

# Normalizing data: MINMAXSCALER
minmaxnormtest = MinMaxScaler().fit(minmaxset)
x_normtest = minmaxnorm.transform(minmaxset)
print(x_normtest.shape)
minmaxtest=pd.DataFrame(x_normtest, columns=minmaxsettest.columns)
minmaxtest
# Out:
# (12835, 5)
#         film_id  rental_duration  rental_rate    length  rating
# 0      0.444444             0.50          0.5  0.388489     0.0
# 1      0.707708             0.25          1.0  0.474820     0.0
# 2      0.788789             1.00          0.5  0.237410     0.0
# 3      0.618619             0.00          0.0  0.827338     0.0
# 4      0.763764             0.00          1.0  0.748201     0.0
# ...         ...              ...          ...       ...     ...
# 12830  0.355355             0.50          0.5  0.402878     0.0
# 12831  0.495495             0.00          0.0  0.956835     0.0
# 12832  0.085085             0.75          1.0  0.539568     0.0
# 12833  0.097097             0.25          1.0  0.194245     0.0
# 12834  0.820821             0.75          0.0  0.992806     0.0
#
# [12835 rows x 5 columns]

# %%
# Resetting the Target index

y_train = y_train.reset_index(drop=True) 

# for y_test as well
y_test = y_test.reset_index(drop=True)

# %%
# Trying a LogReg on the data as is

LR = LogisticRegression(random_state=32, solver='lbfgs')
LR.fit(minmax, y_train)
print("score: ",LR.score(minmaxtest, y_test))

pred = LR.predict(minmaxtest)

print("precision: ",precision_score(y_test,pred))
print("recall: ",recall_score(y_test,pred))
print("f1: ",f1_score(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-54be880e72b7> in <module>
#       3 LR = LogisticRegression(random_state=32, solver='lbfgs')
#       4 LR.fit(minmax, y_train)
# ----> 5 print("score: ",LR.score(minmaxtest, y_test))
#       6
#       7 pred = LR.predict(minmaxtest)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     498         """
#     499         from .metrics import accuracy_score
# --> 500         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     501
#     502     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
# ...
